# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('movies_data_processed.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4996 entries, 0 to 4995
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          4996 non-null   object
#  1   genres        4996 non-null   object
#  2   type          4996 non-null   object
#  3   rating        4863 non-null   float64
#  4   no_of_votes   4863 non-null   float64
#  5   meta_score    2143 non-null   float64
#  6   release_date  4946 non-null   float64
#  7   gross         2084 non-null   float64
#  8   budget        1805 non-null   float64
#  9   countries     4969 non-null   object
#  10  url           4996 non-null   object
#  11  ROI           1612 non-null   float64
#  12  result        4996 non-null   object
# dtypes: float64(7), object(6)
# memory usage: 507.5+ KB

# %%
df.dropna(subset=['release_date', 'gross'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2084 entries, 1 to 4995
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          2084 non-null   object
#  1   genres        2084 non-null   object
#  2   type          2084 non-null   object
#  3   rating        2084 non-null   float64
#  4   no_of_votes   2084 non-null   float64
#  5   meta_score    1930 non-null   float64
#  6   release_date  2084 non-null   float64
#  7   gross         2084 non-null   float64
#  8   budget        1612 non-null   float64
#  9   countries     2084 non-null   object
#  10  url           2084 non-null   object
#  11  ROI           1612 non-null   float64
#  12  result        2084 non-null   object
# dtypes: float64(7), object(6)
# memory usage: 227.9+ KB

# %%
df
# Out:
#                                   name  \
# 1                           Love Hurts
# 2               The Quick and the Dead
# 5         Puss in Boots: The Last Wish
# 15                   The Fifth Element
# 18                            Superman
# ...                                ...
# 4987                      Far and Away
# 4988                        Pale Rider
# 4990                     Shanghai Noon
# 4994                          The Duel
# 4995  Spirit: Stallion of the Cimarron
#
#                                                  genres   type  rating  \
# 1                          Martial Arts, Action, Comedy  Movie     5.3
# 2             Action, Drama, Romance, Thriller, Western  Movie     6.5
# 5     Animal Adventure, Computer Animation, Fairy Ta...  Movie     7.8
# 15    Sci-Fi Epic, Space Sci-Fi, Action, Adventure, ...  Movie     7.6
# 18    Sci-Fi Epic, Superhero, Urban Adventure, Actio...  Movie     7.4
# ...                                                 ...    ...     ...
# 4987  Romantic Epic, Western Epic, Adventure, Drama,...  Movie     6.6
# 4988                                     Drama, Western  Movie     7.3
# 4990  Buddy Comedy, Martial Arts, Action, Adventure,...  Movie     6.6
# 4994                                     Drama, Western  Movie     5.8
# 4995  Animal Adventure, Hand-Drawn Animation, Advent...  Movie     7.2
#
#       no_of_votes  meta_score  release_date        gross      budget  \
# 1          6800.0        34.0        2025.0   17235040.0  18000000.0
# 2        107000.0        49.0        1995.0   18636537.0  32000000.0
# 5        200000.0        73.0        2022.0  481757663.0  90000000.0
# 15       524000.0        52.0        1997.0  263920180.0         NaN
# 18       195000.0        82.0        1978.0  300478449.0  55000000.0
# ...           ...         ...           ...          ...         ...
# 4987      70000.0        49.0        1992.0  137783840.0  60000000.0
# 4988      67000.0        61.0        1985.0   41410568.0   6900000.0
# 4990     138000.0        77.0        2000.0   99274467.0  55000000.0
# 4994      12000.0        42.0        2016.0      20672.0  10000000.0
# 4995      90000.0        52.0        2002.0  122563539.0  80000000.0
#
#                                               countries  \
# 1                                         United States
# 2                                  United States, Japan
# 5                                  United States, Japan
# 15                               France, United Kingdom
# 18    United States, United Kingdom, Switzerland, Pa...
# ...                                                 ...
# 4987                                      United States
# 4988                                      United States
# 4990                           United States, Hong Kong
# 4994                                      United States
# 4995                              United States, Canada
#
#                                                     url       ROI   result
# 1     https://www.imdb.com/title/tt30788842/?ref_=sr... -0.042498     Fail
# 2     https://www.imdb.com/title/tt0114214/?ref_=sr_... -0.417608  Success
# 5     https://www.imdb.com/title/tt3915174/?ref_=sr_...  4.352863  Success
# 15    https://www.imdb.com/title/tt0119116/?ref_=sr_...       NaN  Success
# 18    https://www.imdb.com/title/tt0078346/?ref_=sr_...  4.463245  Success
# ...                                                 ...       ...      ...
# 4987  https://www.imdb.com/title/tt0104231/?ref_=sr_...  1.296397  Success
# 4988  https://www.imdb.com/title/tt0089767/?ref_=sr_...  5.001532  Success
# 4990  https://www.imdb.com/title/tt0184894/?ref_=sr_...  0.804990  Success
# 4994  https://www.imdb.com/title/tt2436682/?ref_=sr_... -0.997933     Fail
# 4995  https://www.imdb.com/title/tt0166813/?ref_=sr_...  0.532044  Success
#
# [2084 rows x 13 columns]

# %%
average_gross_by_year = df.groupby('release_date')['gross'].mean().reset_index()
average_gross_by_year = average_gross_by_year[average_gross_by_year['release_date'] <= 2024]
# Bước 3: Vẽ biểu đồ đường
plt.figure(figsize=(10, 6))  # Kích thước biểu đồ
plt.plot(average_gross_by_year['release_date'], average_gross_by_year['gross'], marker='o')
plt.title('Trung bình doanh thu theo năm phát hành')  # Tiêu đề biểu đồ
plt.xlabel('Năm phát hành')  # Nhãn trục x
plt.ylabel('Trung bình doanh thu')  # Nhãn trục y
plt.grid(True)  # Thêm lưới để dễ quan sát
plt.show()  # Hiển thị biểu đồ
